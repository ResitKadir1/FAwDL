# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
#IMPORT LIBRARIES
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras.preprocessing import image
import scipy.io
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import tensorflow
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from tensorflow.keras import metrics
from tensorflow.keras.models import model_from_json
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from helperScript import *

# %%
#IMPORT DATASETS AND PATH 
Analyses_outputs = r"C:\Users\T-x23\Downloads\Face_Analyses\model_build\Analyses_outputs"
plots = r"C:\Users\T-x23\Downloads\bsc\model_building\plots"
models =r"C:\Users\T-x23\Downloads\bsc\model_building\models"
mat = scipy.io.loadmat(r"C:\Users\T-x23\Downloads\Son\datasets\wiki_crop\wiki_crop\wiki.mat")
cols = ["dob", "photo_taken", "full_path", "gender", "name", "face_location", "face_score", "second_face_score"]
instances = mat['wiki'][0][0][0].shape[1]
df = pd.DataFrame(index = range(0,instances), columns = cols)
for i in mat:
    if i == "wiki":
        current_array = mat[i][0][0]
        for j in range(len(current_array)):
            df[cols[j]] = pd.DataFrame(current_array[j][0])

# %%
#CLEANING DATASET
df = clean_data(df)

# %%
#drop unnecessary columns
df = df.drop(columns = ['dob','photo_taken','name','face_score','second_face_score','face_location'])
gender_dist = df['gender'].value_counts().sort_index()
gender_dist.to_csv(plots+"\gender_dist.csv")
print("Gender distribution",gender_dist)
classes = 2 #0: woman, 1: man
# Out:
# Gender distribution 0.0     6580
# 1.0    15575
# Name: gender, dtype: int64

# %%
#DATA PREPROCESSING
df['pixels'] = df['full_path'].apply(getImagePixels)
target = df['gender'].values
target_classes = to_categorical(target, classes)
features = feature_normalization(df)

# %%
#split train test
train_x, test_x, train_y, test_y = train_test_split(features, target_classes, test_size=0.30)

# %%
#get vggfacemodel
model = VggFaceModel()
model.load_weights(r"C:\Users\T-x23\Downloads\tensorflow-101-master\tensorflow-101-master\python\vgg_face_weights.h5")

# %%
#
model = freeze_layers(model)
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath=models+'/gender_model_son.h5', verbose=1, save_best_only=True, mode = 'auto')

# %%
#MODEL COMPILING

scores = []
epochs = 250
batch_size = 256
for i in range(epochs):
    print("epoch ",i)
    ix_train = np.random.choice(train_x.shape[0], size=batch_size)
    score = model.fit(train_x[ix_train], train_y[ix_train], epochs=1, validation_data=(test_x, test_y), callbacks=[checkpointer])
    scores.append(score)
    model.save_weights(models+'\gender_model_son1.h5')
    model_json = model.to_json()
    with open(models+"\gender_model_son1.json", "w") as json_file:
        json_file.write(model_json)
# Out:
# epoch  0
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 7s - loss: 0.6784 - accuracy: 0.8438
# Epoch 00001: val_loss improved from inf to 126.73581, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 59s 922ms/sample - loss: 50.8523 - accuracy: 0.7344 - val_loss: 126.7358 - val_accuracy: 0.2965
# epoch  1
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 127.8623 - accuracy: 0.2812
# Epoch 00001: val_loss improved from 126.73581 to 17.58482, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 791ms/sample - loss: 64.4563 - accuracy: 0.4375 - val_loss: 17.5848 - val_accuracy: 0.7035
# epoch  2
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 23.4355 - accuracy: 0.5938
# Epoch 00001: val_loss improved from 17.58482 to 0.62102, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 791ms/sample - loss: 13.4869 - accuracy: 0.6250 - val_loss: 0.6210 - val_accuracy: 0.7342
# epoch  3
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.4306 - accuracy: 0.7812
# Epoch 00001: val_loss did not improve from 0.62102
# 64/64 [==============================] - 49s 762ms/sample - loss: 2.4953 - accuracy: 0.5312 - val_loss: 9.4715 - val_accuracy: 0.7035
# epoch  4
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 9.4176 - accuracy: 0.7188
# Epoch 00001: val_loss did not improve from 0.62102
# 64/64 [==============================] - 49s 762ms/sample - loss: 8.1878 - accuracy: 0.6875 - val_loss: 2.7291 - val_accuracy: 0.7035
# epoch  5
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 2.2454 - accuracy: 0.8125
# Epoch 00001: val_loss improved from 0.62102 to 0.60143, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 798ms/sample - loss: 1.5502 - accuracy: 0.7344 - val_loss: 0.6014 - val_accuracy: 0.6465
# epoch  6
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.6589 - accuracy: 0.6875
# Epoch 00001: val_loss improved from 0.60143 to 0.39469, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 795ms/sample - loss: 0.9055 - accuracy: 0.6875 - val_loss: 0.3947 - val_accuracy: 0.8420
# epoch  7
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.8693 - accuracy: 0.7500
# Epoch 00001: val_loss improved from 0.39469 to 0.38553, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 796ms/sample - loss: 0.5858 - accuracy: 0.8125 - val_loss: 0.3855 - val_accuracy: 0.8446
# epoch  8
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.4428 - accuracy: 0.8750
# Epoch 00001: val_loss improved from 0.38553 to 0.15952, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 796ms/sample - loss: 0.5957 - accuracy: 0.8125 - val_loss: 0.1595 - val_accuracy: 0.9352
# epoch  9
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.1576 - accuracy: 0.9062
# Epoch 00001: val_loss did not improve from 0.15952
# 64/64 [==============================] - 49s 763ms/sample - loss: 0.3315 - accuracy: 0.8750 - val_loss: 0.1815 - val_accuracy: 0.9337
# epoch  10
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.4122 - accuracy: 0.9062
# Epoch 00001: val_loss did not improve from 0.15952
# 64/64 [==============================] - 49s 766ms/sample - loss: 0.3664 - accuracy: 0.8906 - val_loss: 0.2792 - val_accuracy: 0.9102
# epoch  11
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 1.3855 - accuracy: 0.8438
# Epoch 00001: val_loss did not improve from 0.15952
# 64/64 [==============================] - 49s 765ms/sample - loss: 1.1116 - accuracy: 0.7969 - val_loss: 0.2158 - val_accuracy: 0.9361
# epoch  12
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.3662 - accuracy: 0.9375
# Epoch 00001: val_loss did not improve from 0.15952
# 64/64 [==============================] - 49s 766ms/sample - loss: 0.2564 - accuracy: 0.9375 - val_loss: 0.4522 - val_accuracy: 0.8780
# epoch  13
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 1.1704 - accuracy: 0.8438
# Epoch 00001: val_loss improved from 0.15952 to 0.13495, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 799ms/sample - loss: 0.6808 - accuracy: 0.8906 - val_loss: 0.1350 - val_accuracy: 0.9520
# epoch  14
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.3689 - accuracy: 0.8750
# Epoch 00001: val_loss did not improve from 0.13495
# 64/64 [==============================] - 49s 764ms/sample - loss: 0.5953 - accuracy: 0.8281 - val_loss: 0.2181 - val_accuracy: 0.9130
# epoch  15
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.4901 - accuracy: 0.8438
# Epoch 00001: val_loss improved from 0.13495 to 0.12545, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 797ms/sample - loss: 0.4225 - accuracy: 0.8438 - val_loss: 0.1254 - val_accuracy: 0.9556
# epoch  16
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.1438 - accuracy: 0.9062
# Epoch 00001: val_loss improved from 0.12545 to 0.11922, saving model to C:\Users\T-x23\Downloads\bsc\model_building\models/gender_model_son.h5
# 64/64 [==============================] - 51s 793ms/sample - loss: 0.2332 - accuracy: 0.9219 - val_loss: 0.1192 - val_accuracy: 0.9604
# epoch  17
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.1154 - accuracy: 0.9688
# Epoch 00001: val_loss did not improve from 0.11922
# 64/64 [==============================] - 49s 765ms/sample - loss: 0.0734 - accuracy: 0.9844 - val_loss: 0.1360 - val_accuracy: 0.9562
# epoch  18
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.3921 - accuracy: 0.9375
# Epoch 00001: val_loss did not improve from 0.11922
# 64/64 [==============================] - 49s 766ms/sample - loss: 0.2893 - accuracy: 0.9531 - val_loss: 0.1450 - val_accuracy: 0.9567
# epoch  19
# Train on 64 samples, validate on 6647 samples
# 32/64 [==============>...............] - ETA: 0s - loss: 0.1332 - accuracy: 0.9688
# Epoch 00001: val_loss did not improve from 0.11922
# 64/64 [==============================] - 49s 765ms/sample - loss: 0.0774 - accuracy: 0.9844 - val_loss: 0.1486 - val_accuracy: 0.9607

# %%
validation_loss_change = []
loss_change = []
for i in range(0, len(scores)):
    validation_loss_change.append(scores[i].history['val_loss'])
    loss_change.append(scores[i].history['loss'])

# %%
#data visualization

plt.plot(validation_loss_change, label='val_loss')
plt.plot(loss_change, label='train_loss')
plt.legend(loc='upper right')
plt.savefig(plots+"\gender loss graph")
plt.title("Gender Loss graph")
plt.show()

# %%
accuracy_loss_change = []
acc_change = []
for i in range(0, len(scores)):
    accuracy_loss_change.append(scores[i].history['accuracy'])
    acc_change.append(scores[i].history['val_accuracy'])

plt.plot(accuracy_loss_change, label='accuracy')
plt.plot(acc_change, label='val_accuracy')
plt.legend(loc='upper right')
plt.savefig(plots + "\Gender accuracy graph")
plt.show()

# %%
model.evaluate(test_x, test_y, verbose=1)
predictions = model.predict(test_x)
# Out:
# 6647/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
pred_list = []
actual_list = []
for i in predictions:
    pred_list.append(np.argmax(i))
for i in test_y: 
    actual_list.append(np.argmax(i))

# %%
cf_matrix =confusion_matrix(actual_list, pred_list)
group_names = ["True Neg","False Pos","False Neg","True Pos"]
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
#ax = sns.heatmap(cf_matrix, annot=True, fmt="d",cmap='Blues')
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt="", cmap='Blues')
plt.title("Confusion Gender Prediction ")
plt.savefig(plots + "\Gender Confusion matrix")

# %%
print(classification_report(actual_list,pred_list))

race_conf_mat = classification_report(actual_list, pred_list,output_dict =True)
race_conf_mat_ = pd.DataFrame(race_conf_mat).transpose()
race_conf_mat_.to_csv(Analyses_outputs+"/Gender_conf_matrix_report.csv")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      1971
#            1       0.97      0.97      0.97      4676
#
#     accuracy                           0.96      6647
#    macro avg       0.95      0.95      0.95      6647
# weighted avg       0.96      0.96      0.96      6647

# %%
#Try on Custom Dataset



races = ["woman","man"]

demo_set = ['bruno_mars.png', 'kim.png',"ind.png" ]


for file in demo_set:
    path = 'demo/%s' % (file) 
    img = image.load_img(path, grayscale=False, target_size=(224, 224, 3))
    img = image.img_to_array(img).reshape(1, -1)[0]
    img = img.reshape(224, 224, 3)
    img = img / 255
    
    plt.imshow(img)
    plt.show()
    
    img = np.expand_dims(img, axis=0) 

    prediction_proba = model.predict(img)

    print("Prediction: ",races[np.argmax(prediction_proba)])
    print("---------------------------")
# Out:
# Prediction:  man
# ---------------------------
# Prediction:  man
# ---------------------------
# Prediction:  woman
# ---------------------------
